# %%
## Make a pickle file with the df for the given:
# exp (e.g. 'FR1')
# subs
# selected_period (e.g. 'encoding')

# this will be used to run createEventsForDF.py in parallel by Slurm

# %%
import pandas as pd; pd.set_option('display.max_columns', 30); pd.set_option('display.max_rows', 100)
import numpy as np
from cmlreaders import CMLReader, get_data_index
from ptsa.data.filters import ButterworthFilter, ResampleFilter, MorletWaveletFilter
import xarray as xarray
import sys
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import *
from copy import copy
from scipy import stats
from scipy.stats import zscore
import pickle
plt.rcParams['pdf.fonttype'] = 42; plt.rcParams['ps.fonttype'] = 42 # fix fonts for Illustrator
sys.path.append('/home1/john/Downloads/ptsa_plot-master/')
sys.path.append('/home1/john/johnModules')
from brain_labels import HPC_labels, ENT_labels, PHC_labels, temporal_lobe_labels,\
                         MFG_labels, IFG_labels, nonHPC_MTL_labels, ENTPHC_labels, AMY_labels
# %load_ext autoreload
# %autoreload
from general import *
from SWRmodule import *  

df = get_data_index("r1") # all RAM subjects
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
### PARAMS ###

exp = 'FR1' # 'FR1' 'catFR1' 'RepFR1'

selected_period = 'encoding'

### END PARAMS ###

# %%
# 575 FR sessions. first 18 of don't load so skip those 
exp_df = df[df.experiment==exp]
if exp == 'FR1':
    exp_df = exp_df[
                    ((df.subject!='R1015J') | (df.session!=0)) & 
                    ((df.subject!='R1063C') | (df.session!=1)) & 
                    ((df.subject!='R1093J') | (~df.session.isin([1,2]))) &
                    ((df.subject!='R1100D') | (~df.session.isin([0,1,2]))) &
                    ((df.subject!='R1120E') | (df.session!=0)) &
                    ((df.subject!='R1122E') | (df.session!=2)) &
                    ((df.subject!='R1154D') | (df.session!=0)) &
                    ((df.subject!='R1186P') | (df.session!=0)) &
                    ((df.subject!='R1201P') | (~df.session.isin([0,1]))) &
                    ((df.subject!='R1216E') | (~df.session.isin([0,1,2]))) &
                    ((df.subject!='R1277J') | (df.session!=0)) &
                    ((df.subject!='R1413D') | (df.session!=0)) & 
                    ((df.subject!='R1123C') | (df.session!=2)) & # artifacts that bleed through channels (see SWR FR1 prob sessions ppt)
                    ((df.subject!='R1151E') | (~df.session.isin([1,2]))) & # more bleed-through artifacts (see same ppt)
                    ((df.subject!='R1275D') | (df.session!=3))  # 3rd session an actual repeat of 2nd session (Paul should have removed from database by now)
    #                 (df.subject!='R1065J') # sub with 9000 trials
                   ] 
elif exp == 'catFR1': 
    exp_df = exp_df[
                    ((df.subject!='R1044J') | (df.session!=0)) & # too few trials to do pg pairwise corr
                    ((df.subject!='R1491T') | (~df.session.isin([1,3,5]))) & # too few trials to do pg pairwise corr
                    ((df.subject!='R1486J') | (~df.session.isin([4,5,6,7]))) & # repeated data...will be removed at some point... @@
                    ((df.subject!='R1501J') | (~df.session.isin([0,1,2,3,4,5]))) & # these weren't catFR1 (and they don't load right anyway)
                    ((df.subject!='R1235E') | (df.session!=0)) & # split EEG filenames error...documented on Asana
                    ((df.subject!='R1310J') | (df.session!=1)) & # session 1 is just a repeat of session 0
                    ((df.subject!='R1239E') | (df.session!=0)) # some correlated noise (can see in catFR1 problem sessions ppt)
    ]
elif exp == 'RepFR1':
    exp_df = exp_df[
                    (df.subject!='R1564J') # clearly something wrong with these EEG when looking at ripple raster
                    ]
exp_df.shape
# exp_df = exp_df[257:] # for catFR1 this is R1385E-onwwards
# exp_df = exp_df[472:] # for FR1 this is R1385E-onwwards
# exp_df = exp_df[468:] # for catFR1 this is R1525J-onwards
# exp_df
# Out:
# /home1/john/anaconda3/envs/env1/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# (567, 17)

# %%
# sub lists I've been using to explore FR1 

# subs = ['R1010J'] #'R1385E'] # ['R1065J'] #
# subs = ['R1002P','R1003P','R1006P','R1010J','R1112M','R1163T'] # initial 6 for hippocampus

# subs = subs+['R1001P','R1092J','R1151E','R1320D'] # additional subs with issues that I resolved with various RR and corr thresholds
# subs = ['R1112M','R1018P','R1020J','R1022J','R1023J','R1026D','R1027J'] # 7 with entorhinal
# subs = ['R1010J','R1112M'] # original 2 # R1108J beatiful catFR1 data; R1065J magical subject (like with FR1)
# subs = ['R1112M','R1163T'] # subjects with FR1 and catFR1. SRs of 1000 and 500 tho
# subs = ['R1151E'] # all channels X sessions get removed but 3 after 60/180 hz line removal
# these should all be worked out now. See SWR FR1 problem sessions PPT on Box for details of each
# subs = ['R1299T','R1332M','R1397D','R1349T','R1339D','R1337E','R1275D','R1151E','R1123C','R1120E','R1045E'] # final surrounding_recall problem subs after looking at huge raster!
# subs = ['R1308T','R1338T','R1358T'] # these guys had weird SRs and some loading problems when I went to whole_retrieval analysis...fixed with rounding
# subs = ['R1023J','R1101T','R1148P','R1368T','R1323T','R1334T'] # single session subs with memory allocation errors in ClusterRun
# subs = ['R1006P','R1010J','R1030J','R1032D','R1049J','R1051J','R1052E','R1054J','R1093J','R1098D','R1104D','R1108J','R1111M',
#         'R1115T','R1118N','R1124J','R1207J','R1230J','R1316T','R1329T','R1323T','R1337E','R1367D'] # subs that didn't load on 2020-07-04 encoding run
# subs = ['R1368T','R1461T','R1463E'] # subs with particularly low localization.pair matches in pairs...see Excel in loading info on Box for details
# subs = ['R1433E','R1355T','R1367D','R1368T'] # subs with "ca3" or "dg"
# subs = ['R1001P'] # subject with over 8000 FR1 trials X electrodes
# bad_subs = ['R1433E','R1051J'] # no electrode cats
# subs = ['R1379E','R1385E','R1387E','R1394E','R1402E'] # partial beep subs
# subs = ['R1379E','R1402E','R1396T','R1395M','R1415T','R1389J','R1404E']  # test subs for eeg offset correction
# subs = ['R1054J','R1345D','R1048E','R1328E','R1308T', # first 2 are sr ≥ 1000. 3rd is 500 Hz.
#         'R1137E','R1136N','R1094T','R1122E','R1385E']#, # nice example FR1 subs used in Fig. 2
#         'R1405E','R1486J','R1501J'] # adding in 3 catFR only patients that will go into Fig. 4
# subs = ['R1120E','R1349T','R1397D','R1332M','R1299T'] # FR1 patients with electrode search ranges limited per SWR problem sessions doc on Box
# subs = ['R1269E','R1328E','R1367D','R1397D','R1405E','R1405E','R1447M','R1469D'] # catFR1 patients with electrode search changes limited
# subs = ['R1065J','R1492J','R1525J'] # killer subs
# subs = ['R1030J','R1035M'] # MFG subs
# subs = ['R1207J'] #'R1035M'] #['R1108J'] # R1065J # 'R1035M' #R1086M
# subs = ['R1111M','R1108J','R1191J','R1229M','R1247P','R1264P','R1261P','R1016M','R1065J','R1191J',
#         'R1190P','R1254E','R1337E','R1118N','R1153T','R1156D'] # FR1 patients that are getting encoding memory errors 
# subs = ['R1051J','R1118N','R1154D','R1207J','R1308T','R1311T','R1329T','R1334T','R1336T','R1334T',
#         'R1342M','R1212P','R1346T','R1311T','R1323T','R1329T','R1342M','R1346T','R1367D','R1569T'] # catFR1 memory error patients

# subs = ['R1001P','R1002P','R1003P','R1006P','R1010J','R1018P','R1020J','R1022J', # mimicking test session
#         'R1023J','R1026D','R1027J','R1030J','R1031M','R1032D','R1033D','R1034D']
# subs = ['R1367D'] #['R1525J'] #['R1367D'] #R1065J'

subs = ['R1010J','R1054J','R1048E','R1328E','R1308T',
        'R1137E','R1136N','R1122E','R1112M','R1144E'] # removed R1094T who used Spanish

sub_df = exp_df[(exp_df.subject.isin(subs))  & (exp_df.experiment == exp)] # all sessions for subs
# sub_df = df[(df.subject.isin(subs))  & (df.experiment == exp) & (df.session==1)] # single session
# sub_df = df[(df.experiment == exp) & (df.session == 0)] # all FR subs 
# sub_df = sub_df[0:1]
sub_df
# Out:
#      Recognition                                         all_events  \
# 45           NaN  protocols/r1/subjects/R1010J/experiments/FR1/s...
# 46           NaN  protocols/r1/subjects/R1010J/experiments/FR1/s...
# 247          NaN  protocols/r1/subjects/R1048E/experiments/FR1/s...
# 285          NaN  protocols/r1/subjects/R1054J/experiments/FR1/s...
# 286          NaN  protocols/r1/subjects/R1054J/experiments/FR1/s...
# 647          NaN  protocols/r1/subjects/R1112M/experiments/FR1/s...
# 648          NaN  protocols/r1/subjects/R1112M/experiments/FR1/s...
# 649          NaN  protocols/r1/subjects/R1112M/experiments/FR1/s...
# 726          NaN  protocols/r1/subjects/R1122E/experiments/FR1/s...
# 727          NaN  protocols/r1/subjects/R1122E/experiments/FR1/s...
# 794          NaN  protocols/r1/subjects/R1136N/experiments/FR1/s...
# 795          NaN  protocols/r1/subjects/R1136N/experiments/FR1/s...
# 802          NaN  protocols/r1/subjects/R1137E/experiments/FR1/s...
# 803          NaN  protocols/r1/subjects/R1137E/experiments/FR1/s...
# 804          NaN  protocols/r1/subjects/R1137E/experiments/FR1/s...
# 1639         NaN  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1640         NaN  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1641         NaN  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1642         NaN  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1643         NaN  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1709         NaN  protocols/r1/subjects/R1328E/experiments/FR1/s...
# 1710         NaN  protocols/r1/subjects/R1328E/experiments/FR1/s...
# 1774         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1775         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1776         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1777         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1778         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
#
#                                                contacts experiment  \
# 45    protocols/r1/subjects/R1010J/localizations/0/m...        FR1
# 46    protocols/r1/subjects/R1010J/localizations/0/m...        FR1
# 247   protocols/r1/subjects/R1048E/localizations/0/m...        FR1
# 285   protocols/r1/subjects/R1054J/localizations/0/m...        FR1
# 286   protocols/r1/subjects/R1054J/localizations/0/m...        FR1
# 647   protocols/r1/subjects/R1112M/localizations/0/m...        FR1
# 648   protocols/r1/subjects/R1112M/localizations/0/m...        FR1
# 649   protocols/r1/subjects/R1112M/localizations/0/m...        FR1
# 726   protocols/r1/subjects/R1122E/localizations/0/m...        FR1
# 727   protocols/r1/subjects/R1122E/localizations/0/m...        FR1
# 794   protocols/r1/subjects/R1136N/localizations/0/m...        FR1
# 795   protocols/r1/subjects/R1136N/localizations/0/m...        FR1
# 802   protocols/r1/subjects/R1137E/localizations/0/m...        FR1
# 803   protocols/r1/subjects/R1137E/localizations/0/m...        FR1
# 804   protocols/r1/subjects/R1137E/localizations/0/m...        FR1
# 1639  protocols/r1/subjects/R1308T/localizations/0/m...        FR1
# 1640  protocols/r1/subjects/R1308T/localizations/0/m...        FR1
# 1641  protocols/r1/subjects/R1308T/localizations/0/m...        FR1
# 1642  protocols/r1/subjects/R1308T/localizations/0/m...        FR1
# 1643  protocols/r1/subjects/R1308T/localizations/0/m...        FR1
# 1709  protocols/r1/subjects/R1328E/localizations/0/m...        FR1
# 1710  protocols/r1/subjects/R1328E/localizations/0/m...        FR1
# 1774  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1775  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1776  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1777  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1778  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
#
#      import_type  localization  \
# 45         build             0
# 46         build             0
# 247        build             0
# 285        build             0
# 286        build             0
# 647        build             0
# 648        build             0
# 649        build             0
# 726        build             0
# 727        build             0
# 794        build             0
# 795        build             0
# 802        build             0
# 803        build             0
# 804        build             0
# 1639       build             0
# 1640       build             0
# 1641       build             0
# 1642       build             0
# 1643       build             0
# 1709       build             0
# 1710       build             0
# 1774       build             0
# 1775       build             0
# 1776       build             0
# 1777       build             0
# 1778       build             0
#
#                                             math_events  montage  \
# 45    protocols/r1/subjects/R1010J/experiments/FR1/s...        0
# 46    protocols/r1/subjects/R1010J/experiments/FR1/s...        0
# 247   protocols/r1/subjects/R1048E/experiments/FR1/s...        0
# 285   protocols/r1/subjects/R1054J/experiments/FR1/s...        0
# 286   protocols/r1/subjects/R1054J/experiments/FR1/s...        0
# 647   protocols/r1/subjects/R1112M/experiments/FR1/s...        0
# 648   protocols/r1/subjects/R1112M/experiments/FR1/s...        0
# 649   protocols/r1/subjects/R1112M/experiments/FR1/s...        0
# 726   protocols/r1/subjects/R1122E/experiments/FR1/s...        0
# 727   protocols/r1/subjects/R1122E/experiments/FR1/s...        0
# 794   protocols/r1/subjects/R1136N/experiments/FR1/s...        0
# 795   protocols/r1/subjects/R1136N/experiments/FR1/s...        0
# 802   protocols/r1/subjects/R1137E/experiments/FR1/s...        0
# 803   protocols/r1/subjects/R1137E/experiments/FR1/s...        0
# 804   protocols/r1/subjects/R1137E/experiments/FR1/s...        0
# 1639  protocols/r1/subjects/R1308T/experiments/FR1/s...        0
# 1640  protocols/r1/subjects/R1308T/experiments/FR1/s...        0
# 1641  protocols/r1/subjects/R1308T/experiments/FR1/s...        0
# 1642  protocols/r1/subjects/R1308T/experiments/FR1/s...        0
# 1643  protocols/r1/subjects/R1308T/experiments/FR1/s...        0
# 1709  protocols/r1/subjects/R1328E/experiments/FR1/s...        0
# 1710  protocols/r1/subjects/R1328E/experiments/FR1/s...        0
# 1774  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1775  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1776  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1777  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1778  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
#
#      original_experiment original_session  \
# 45                   NaN                0
# 46                   NaN                1
# 247                  NaN                0
# 285                  NaN                0
# 286                  NaN                1
# 647                  NaN              NaN
# 648                  NaN              NaN
# 649                  NaN              NaN
# 726                  NaN                0
# 727                  NaN                1
# 794                  NaN                0
# 795                  NaN                1
# 802                  NaN                0
# 803                  NaN                1
# 804                  NaN                2
# 1639                 NaN              NaN
# 1640                 NaN              NaN
# 1641                 NaN              NaN
# 1642                 NaN              NaN
# 1643                 NaN              NaN
# 1709                 NaN              NaN
# 1710                 NaN              NaN
# 1774                 NaN              NaN
# 1775                 NaN              NaN
# 1776                 NaN              NaN
# 1777                 NaN              NaN
# 1778                 NaN              NaN
#
#                                                   pairs ps4_events  session  \
# 45    protocols/r1/subjects/R1010J/localizations/0/m...        NaN        0
# 46    protocols/r1/subjects/R1010J/localizations/0/m...        NaN        1
# 247   protocols/r1/subjects/R1048E/localizations/0/m...        NaN        0
# 285   protocols/r1/subjects/R1054J/localizations/0/m...        NaN        0
# 286   protocols/r1/subjects/R1054J/localizations/0/m...        NaN        1
# 647   protocols/r1/subjects/R1112M/localizations/0/m...        NaN        0
# 648   protocols/r1/subjects/R1112M/localizations/0/m...        NaN        1
# 649   protocols/r1/subjects/R1112M/localizations/0/m...        NaN        2
# 726   protocols/r1/subjects/R1122E/localizations/0/m...        NaN        0
# 727   protocols/r1/subjects/R1122E/localizations/0/m...        NaN        1
# 794   protocols/r1/subjects/R1136N/localizations/0/m...        NaN        0
# 795   protocols/r1/subjects/R1136N/localizations/0/m...        NaN        1
# 802   protocols/r1/subjects/R1137E/localizations/0/m...        NaN        0
# 803   protocols/r1/subjects/R1137E/localizations/0/m...        NaN        1
# 804   protocols/r1/subjects/R1137E/localizations/0/m...        NaN        2
# 1639  protocols/r1/subjects/R1308T/localizations/0/m...        NaN        0
# 1640  protocols/r1/subjects/R1308T/localizations/0/m...        NaN        1
# 1641  protocols/r1/subjects/R1308T/localizations/0/m...        NaN        2
# 1642  protocols/r1/subjects/R1308T/localizations/0/m...        NaN        3
# 1643  protocols/r1/subjects/R1308T/localizations/0/m...        NaN        4
# 1709  protocols/r1/subjects/R1328E/localizations/0/m...        NaN        0
# 1710  protocols/r1/subjects/R1328E/localizations/0/m...        NaN        1
# 1774  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        0
# 1775  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        1
# 1776  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        2
# 1777  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        3
# 1778  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        4
#
#      subject subject_alias  system_version  \
# 45    R1010J        R1010J             NaN
# 46    R1010J        R1010J             NaN
# 247   R1048E        R1048E             NaN
# 285   R1054J        R1054J             NaN
# 286   R1054J        R1054J             NaN
# 647   R1112M        R1112M             1.0
# 648   R1112M        R1112M             1.0
# 649   R1112M        R1112M             1.0
# 726   R1122E        R1122E             NaN
# 727   R1122E        R1122E             NaN
# 794   R1136N        R1136N             NaN
# 795   R1136N        R1136N             NaN
# 802   R1137E        R1137E             NaN
# 803   R1137E        R1137E             NaN
# 804   R1137E        R1137E             NaN
# 1639  R1308T        R1308T             3.1
# 1640  R1308T        R1308T             3.1
# 1641  R1308T        R1308T             3.1
# 1642  R1308T        R1308T             3.1
# 1643  R1308T        R1308T             3.1
# 1709  R1328E        R1328E             3.1
# 1710  R1328E        R1328E             3.1
# 1774  R1345D        R1345D             3.1
# 1775  R1345D        R1345D             3.1
# 1776  R1345D        R1345D             3.1
# 1777  R1345D        R1345D             3.1
# 1778  R1345D        R1345D             3.1
#
#                                             task_events
# 45    protocols/r1/subjects/R1010J/experiments/FR1/s...
# 46    protocols/r1/subjects/R1010J/experiments/FR1/s...
# 247   protocols/r1/subjects/R1048E/experiments/FR1/s...
# 285   protocols/r1/subjects/R1054J/experiments/FR1/s...
# 286   protocols/r1/subjects/R1054J/experiments/FR1/s...
# 647   protocols/r1/subjects/R1112M/experiments/FR1/s...
# 648   protocols/r1/subjects/R1112M/experiments/FR1/s...
# 649   protocols/r1/subjects/R1112M/experiments/FR1/s...
# 726   protocols/r1/subjects/R1122E/experiments/FR1/s...
# 727   protocols/r1/subjects/R1122E/experiments/FR1/s...
# 794   protocols/r1/subjects/R1136N/experiments/FR1/s...
# 795   protocols/r1/subjects/R1136N/experiments/FR1/s...
# 802   protocols/r1/subjects/R1137E/experiments/FR1/s...
# 803   protocols/r1/subjects/R1137E/experiments/FR1/s...
# 804   protocols/r1/subjects/R1137E/experiments/FR1/s...
# 1639  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1640  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1641  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1642  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1643  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1709  protocols/r1/subjects/R1328E/experiments/FR1/s...
# 1710  protocols/r1/subjects/R1328E/experiments/FR1/s...
# 1774  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1775  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1776  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1777  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1778  protocols/r1/subjects/R1345D/experiments/FR1/s...

# %% [markdown]
# # in this case just take the full df for these 10 subs

# %%
final_df = sub_df
len(final_df)
final_df.head()
final_df.tail()
# Out:
# 27
#     Recognition                                         all_events  \
# 45          NaN  protocols/r1/subjects/R1010J/experiments/FR1/s...
# 46          NaN  protocols/r1/subjects/R1010J/experiments/FR1/s...
# 247         NaN  protocols/r1/subjects/R1048E/experiments/FR1/s...
# 285         NaN  protocols/r1/subjects/R1054J/experiments/FR1/s...
# 286         NaN  protocols/r1/subjects/R1054J/experiments/FR1/s...
#
#                                               contacts experiment import_type  \
# 45   protocols/r1/subjects/R1010J/localizations/0/m...        FR1       build
# 46   protocols/r1/subjects/R1010J/localizations/0/m...        FR1       build
# 247  protocols/r1/subjects/R1048E/localizations/0/m...        FR1       build
# 285  protocols/r1/subjects/R1054J/localizations/0/m...        FR1       build
# 286  protocols/r1/subjects/R1054J/localizations/0/m...        FR1       build
#
#      localization                                        math_events  montage  \
# 45              0  protocols/r1/subjects/R1010J/experiments/FR1/s...        0
# 46              0  protocols/r1/subjects/R1010J/experiments/FR1/s...        0
# 247             0  protocols/r1/subjects/R1048E/experiments/FR1/s...        0
# 285             0  protocols/r1/subjects/R1054J/experiments/FR1/s...        0
# 286             0  protocols/r1/subjects/R1054J/experiments/FR1/s...        0
#
#     original_experiment original_session  \
# 45                  NaN                0
# 46                  NaN                1
# 247                 NaN                0
# 285                 NaN                0
# 286                 NaN                1
#
#                                                  pairs ps4_events  session  \
# 45   protocols/r1/subjects/R1010J/localizations/0/m...        NaN        0
# 46   protocols/r1/subjects/R1010J/localizations/0/m...        NaN        1
# 247  protocols/r1/subjects/R1048E/localizations/0/m...        NaN        0
# 285  protocols/r1/subjects/R1054J/localizations/0/m...        NaN        0
# 286  protocols/r1/subjects/R1054J/localizations/0/m...        NaN        1
#
#     subject subject_alias  system_version  \
# 45   R1010J        R1010J             NaN
# 46   R1010J        R1010J             NaN
# 247  R1048E        R1048E             NaN
# 285  R1054J        R1054J             NaN
# 286  R1054J        R1054J             NaN
#
#                                            task_events
# 45   protocols/r1/subjects/R1010J/experiments/FR1/s...
# 46   protocols/r1/subjects/R1010J/experiments/FR1/s...
# 247  protocols/r1/subjects/R1048E/experiments/FR1/s...
# 285  protocols/r1/subjects/R1054J/experiments/FR1/s...
# 286  protocols/r1/subjects/R1054J/experiments/FR1/s...
#      Recognition                                         all_events  \
# 1774         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1775         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1776         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1777         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1778         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
#
#                                                contacts experiment  \
# 1774  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1775  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1776  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1777  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1778  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
#
#      import_type  localization  \
# 1774       build             0
# 1775       build             0
# 1776       build             0
# 1777       build             0
# 1778       build             0
#
#                                             math_events  montage  \
# 1774  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1775  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1776  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1777  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1778  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
#
#      original_experiment original_session  \
# 1774                 NaN              NaN
# 1775                 NaN              NaN
# 1776                 NaN              NaN
# 1777                 NaN              NaN
# 1778                 NaN              NaN
#
#                                                   pairs ps4_events  session  \
# 1774  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        0
# 1775  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        1
# 1776  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        2
# 1777  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        3
# 1778  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        4
#
#      subject subject_alias  system_version  \
# 1774  R1345D        R1345D             3.1
# 1775  R1345D        R1345D             3.1
# 1776  R1345D        R1345D             3.1
# 1777  R1345D        R1345D             3.1
# 1778  R1345D        R1345D             3.1
#
#                                             task_events
# 1774  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1775  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1776  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1777  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1778  protocols/r1/subjects/R1345D/experiments/FR1/s...

# %%
save_df = 1

if save_df == 1:

    import dill
    print("SAVING TEMP DF")
    with open(f'/scratch/john/SWRrefactored/patient_info/temp_dfSWR_{selected_period}_{exp}.p', 'wb') as f: 
        dill.dump(list(final_df.itertuples()) ,f)

    params = []
    for i in range(len(list(final_df.itertuples()) )):
        params.append(i)

    print("Number of sessions in final_df: ", len(params))
    print("From these subjects:")
    print(np.unique(final_df.subject))
# Out:
# SAVING TEMP DF
# Number of sessions in final_df:  27
# From these subjects:
# ['R1010J' 'R1048E' 'R1054J' 'R1112M' 'R1122E' 'R1136N' 'R1137E' 'R1308T'
#  'R1328E' 'R1345D']

# %% [markdown]
# # If you want to make a df for a specific region:

# %%
selected_region = HPC_labels #ENTPHC_labels #

import warnings
# Ignore specific warnings
warnings.filterwarnings("ignore", category=UserWarning, message="Lab-specific readers may be moved to the cmlreaders package")
warnings.filterwarnings("ignore", category=UserWarning, message="Could not load MNI coordinates")
warnings.filterwarnings("ignore", category=UserWarning, message="Lab-specific readers may be moved to the cmlreaders package")
warnings.filterwarnings("ignore", category=FutureWarning, message="Could not load MNI coordinates")
warnings.filterwarnings("ignore", category=FutureWarning, message="Lab-specific readers may be moved to the cmlreaders package")
warnings.filterwarnings("ignore", category=FutureWarning, message="pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead")


# get region label
if selected_region == HPC_labels:
    region_name = 'HPC'
elif selected_region == ENT_labels:
    region_name = 'ENT'
elif selected_region == PHC_labels:
    region_name = 'PHC'
elif selected_region == temporal_lobe_labels:
    region_name = 'TEMPORALLOBE'
elif selected_region == MFG_labels:
    region_name = 'MFG'
elif selected_region == IFG_labels:
    region_name = 'IFG'
elif selected_region == nonHPC_MTL_labels:
    region_name = 'nonHPC_MTL'    
elif selected_region == ENTPHC_labels:
    region_name = 'ENTPHC' 
elif selected_region == AMY_labels:
    region_name = 'AMY'

data = {
    'HPC_names': [],
    'sub_names': [],
    'sub_sess_names': [],
    'electrode_labels': [],
    'channel_nums': []
}

# Initialize a set to keep track of subjects that pass the if statement
passed_subjects = set()

for row in sub_df.itertuples():   
    sub = row.subject
    session = row.session
    exp = row.experiment
    mont = int(row.montage)
    loc = int(row.localization)
    reader = CMLReadDFRow(row)
    evs = reader.load('task_events')
    word_evs = evs[evs['type'] == 'WORD']

    pairs = reader.load('pairs')
    try:
        localizations = reader.load('localization')
    except:
        localizations = []
    tal_struct, bipolar_pairs, mpchans = get_bp_tal_struct(sub, montage=mont, localization=loc)
    elec_regions, atlas_type, pair_number, has_stein_das = get_elec_regions(localizations, pairs)

    try:
        elec_cats = reader.load('electrode_categories')
    except:
        if remove_soz_ictal == True:
            print("Remove soz ictal is true")
            add_session_to_exclude_list("Remove soz ictal is true")
            sys.exit()
        else: 
            elec_cats = []
  
    bad_bp_mask = getBadChannels(tal_struct, elec_cats, remove_soz_ictal)

    electrode_search_range = getElectrodeRanges(elec_regions, exp, sub, session, mont)

    for channel in electrode_search_range:
        if (elec_regions[channel] in selected_region) & (bad_bp_mask[channel] == 0):
            data['HPC_names'].append(elec_regions[channel])
            data['sub_names'].append(sub)
            data['sub_sess_names'].append(f"{sub}-{session}")
            data['electrode_labels'].append(pairs.iloc[channel].label)
            data['channel_nums'].append(channel)
#             print('Cumulative array size after channel: ' + str(channel))
            passed_subjects.add(sub)

cliff_notes_df = pd.DataFrame(data)

# Create final_df
selected_sub_df = sub_df[sub_df['subject'].isin(passed_subjects)]
print('Done making df for region: '+region_name)
selected_sub_df
# Out:
# Done making df for region: HPC
#      Recognition                                         all_events  \
# 45           NaN  protocols/r1/subjects/R1010J/experiments/FR1/s...
# 46           NaN  protocols/r1/subjects/R1010J/experiments/FR1/s...
# 247          NaN  protocols/r1/subjects/R1048E/experiments/FR1/s...
# 285          NaN  protocols/r1/subjects/R1054J/experiments/FR1/s...
# 286          NaN  protocols/r1/subjects/R1054J/experiments/FR1/s...
# 647          NaN  protocols/r1/subjects/R1112M/experiments/FR1/s...
# 648          NaN  protocols/r1/subjects/R1112M/experiments/FR1/s...
# 649          NaN  protocols/r1/subjects/R1112M/experiments/FR1/s...
# 726          NaN  protocols/r1/subjects/R1122E/experiments/FR1/s...
# 727          NaN  protocols/r1/subjects/R1122E/experiments/FR1/s...
# 794          NaN  protocols/r1/subjects/R1136N/experiments/FR1/s...
# 795          NaN  protocols/r1/subjects/R1136N/experiments/FR1/s...
# 802          NaN  protocols/r1/subjects/R1137E/experiments/FR1/s...
# 803          NaN  protocols/r1/subjects/R1137E/experiments/FR1/s...
# 804          NaN  protocols/r1/subjects/R1137E/experiments/FR1/s...
# 1639         NaN  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1640         NaN  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1641         NaN  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1642         NaN  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1643         NaN  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1709         NaN  protocols/r1/subjects/R1328E/experiments/FR1/s...
# 1710         NaN  protocols/r1/subjects/R1328E/experiments/FR1/s...
# 1774         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1775         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1776         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1777         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1778         NaN  protocols/r1/subjects/R1345D/experiments/FR1/s...
#
#                                                contacts experiment  \
# 45    protocols/r1/subjects/R1010J/localizations/0/m...        FR1
# 46    protocols/r1/subjects/R1010J/localizations/0/m...        FR1
# 247   protocols/r1/subjects/R1048E/localizations/0/m...        FR1
# 285   protocols/r1/subjects/R1054J/localizations/0/m...        FR1
# 286   protocols/r1/subjects/R1054J/localizations/0/m...        FR1
# 647   protocols/r1/subjects/R1112M/localizations/0/m...        FR1
# 648   protocols/r1/subjects/R1112M/localizations/0/m...        FR1
# 649   protocols/r1/subjects/R1112M/localizations/0/m...        FR1
# 726   protocols/r1/subjects/R1122E/localizations/0/m...        FR1
# 727   protocols/r1/subjects/R1122E/localizations/0/m...        FR1
# 794   protocols/r1/subjects/R1136N/localizations/0/m...        FR1
# 795   protocols/r1/subjects/R1136N/localizations/0/m...        FR1
# 802   protocols/r1/subjects/R1137E/localizations/0/m...        FR1
# 803   protocols/r1/subjects/R1137E/localizations/0/m...        FR1
# 804   protocols/r1/subjects/R1137E/localizations/0/m...        FR1
# 1639  protocols/r1/subjects/R1308T/localizations/0/m...        FR1
# 1640  protocols/r1/subjects/R1308T/localizations/0/m...        FR1
# 1641  protocols/r1/subjects/R1308T/localizations/0/m...        FR1
# 1642  protocols/r1/subjects/R1308T/localizations/0/m...        FR1
# 1643  protocols/r1/subjects/R1308T/localizations/0/m...        FR1
# 1709  protocols/r1/subjects/R1328E/localizations/0/m...        FR1
# 1710  protocols/r1/subjects/R1328E/localizations/0/m...        FR1
# 1774  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1775  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1776  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1777  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
# 1778  protocols/r1/subjects/R1345D/localizations/0/m...        FR1
#
#      import_type  localization  \
# 45         build             0
# 46         build             0
# 247        build             0
# 285        build             0
# 286        build             0
# 647        build             0
# 648        build             0
# 649        build             0
# 726        build             0
# 727        build             0
# 794        build             0
# 795        build             0
# 802        build             0
# 803        build             0
# 804        build             0
# 1639       build             0
# 1640       build             0
# 1641       build             0
# 1642       build             0
# 1643       build             0
# 1709       build             0
# 1710       build             0
# 1774       build             0
# 1775       build             0
# 1776       build             0
# 1777       build             0
# 1778       build             0
#
#                                             math_events  montage  \
# 45    protocols/r1/subjects/R1010J/experiments/FR1/s...        0
# 46    protocols/r1/subjects/R1010J/experiments/FR1/s...        0
# 247   protocols/r1/subjects/R1048E/experiments/FR1/s...        0
# 285   protocols/r1/subjects/R1054J/experiments/FR1/s...        0
# 286   protocols/r1/subjects/R1054J/experiments/FR1/s...        0
# 647   protocols/r1/subjects/R1112M/experiments/FR1/s...        0
# 648   protocols/r1/subjects/R1112M/experiments/FR1/s...        0
# 649   protocols/r1/subjects/R1112M/experiments/FR1/s...        0
# 726   protocols/r1/subjects/R1122E/experiments/FR1/s...        0
# 727   protocols/r1/subjects/R1122E/experiments/FR1/s...        0
# 794   protocols/r1/subjects/R1136N/experiments/FR1/s...        0
# 795   protocols/r1/subjects/R1136N/experiments/FR1/s...        0
# 802   protocols/r1/subjects/R1137E/experiments/FR1/s...        0
# 803   protocols/r1/subjects/R1137E/experiments/FR1/s...        0
# 804   protocols/r1/subjects/R1137E/experiments/FR1/s...        0
# 1639  protocols/r1/subjects/R1308T/experiments/FR1/s...        0
# 1640  protocols/r1/subjects/R1308T/experiments/FR1/s...        0
# 1641  protocols/r1/subjects/R1308T/experiments/FR1/s...        0
# 1642  protocols/r1/subjects/R1308T/experiments/FR1/s...        0
# 1643  protocols/r1/subjects/R1308T/experiments/FR1/s...        0
# 1709  protocols/r1/subjects/R1328E/experiments/FR1/s...        0
# 1710  protocols/r1/subjects/R1328E/experiments/FR1/s...        0
# 1774  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1775  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1776  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1777  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
# 1778  protocols/r1/subjects/R1345D/experiments/FR1/s...        0
#
#      original_experiment original_session  \
# 45                   NaN                0
# 46                   NaN                1
# 247                  NaN                0
# 285                  NaN                0
# 286                  NaN                1
# 647                  NaN              NaN
# 648                  NaN              NaN
# 649                  NaN              NaN
# 726                  NaN                0
# 727                  NaN                1
# 794                  NaN                0
# 795                  NaN                1
# 802                  NaN                0
# 803                  NaN                1
# 804                  NaN                2
# 1639                 NaN              NaN
# 1640                 NaN              NaN
# 1641                 NaN              NaN
# 1642                 NaN              NaN
# 1643                 NaN              NaN
# 1709                 NaN              NaN
# 1710                 NaN              NaN
# 1774                 NaN              NaN
# 1775                 NaN              NaN
# 1776                 NaN              NaN
# 1777                 NaN              NaN
# 1778                 NaN              NaN
#
#                                                   pairs ps4_events  session  \
# 45    protocols/r1/subjects/R1010J/localizations/0/m...        NaN        0
# 46    protocols/r1/subjects/R1010J/localizations/0/m...        NaN        1
# 247   protocols/r1/subjects/R1048E/localizations/0/m...        NaN        0
# 285   protocols/r1/subjects/R1054J/localizations/0/m...        NaN        0
# 286   protocols/r1/subjects/R1054J/localizations/0/m...        NaN        1
# 647   protocols/r1/subjects/R1112M/localizations/0/m...        NaN        0
# 648   protocols/r1/subjects/R1112M/localizations/0/m...        NaN        1
# 649   protocols/r1/subjects/R1112M/localizations/0/m...        NaN        2
# 726   protocols/r1/subjects/R1122E/localizations/0/m...        NaN        0
# 727   protocols/r1/subjects/R1122E/localizations/0/m...        NaN        1
# 794   protocols/r1/subjects/R1136N/localizations/0/m...        NaN        0
# 795   protocols/r1/subjects/R1136N/localizations/0/m...        NaN        1
# 802   protocols/r1/subjects/R1137E/localizations/0/m...        NaN        0
# 803   protocols/r1/subjects/R1137E/localizations/0/m...        NaN        1
# 804   protocols/r1/subjects/R1137E/localizations/0/m...        NaN        2
# 1639  protocols/r1/subjects/R1308T/localizations/0/m...        NaN        0
# 1640  protocols/r1/subjects/R1308T/localizations/0/m...        NaN        1
# 1641  protocols/r1/subjects/R1308T/localizations/0/m...        NaN        2
# 1642  protocols/r1/subjects/R1308T/localizations/0/m...        NaN        3
# 1643  protocols/r1/subjects/R1308T/localizations/0/m...        NaN        4
# 1709  protocols/r1/subjects/R1328E/localizations/0/m...        NaN        0
# 1710  protocols/r1/subjects/R1328E/localizations/0/m...        NaN        1
# 1774  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        0
# 1775  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        1
# 1776  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        2
# 1777  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        3
# 1778  protocols/r1/subjects/R1345D/localizations/0/m...        NaN        4
#
#      subject subject_alias  system_version  \
# 45    R1010J        R1010J             NaN
# 46    R1010J        R1010J             NaN
# 247   R1048E        R1048E             NaN
# 285   R1054J        R1054J             NaN
# 286   R1054J        R1054J             NaN
# 647   R1112M        R1112M             1.0
# 648   R1112M        R1112M             1.0
# 649   R1112M        R1112M             1.0
# 726   R1122E        R1122E             NaN
# 727   R1122E        R1122E             NaN
# 794   R1136N        R1136N             NaN
# 795   R1136N        R1136N             NaN
# 802   R1137E        R1137E             NaN
# 803   R1137E        R1137E             NaN
# 804   R1137E        R1137E             NaN
# 1639  R1308T        R1308T             3.1
# 1640  R1308T        R1308T             3.1
# 1641  R1308T        R1308T             3.1
# 1642  R1308T        R1308T             3.1
# 1643  R1308T        R1308T             3.1
# 1709  R1328E        R1328E             3.1
# 1710  R1328E        R1328E             3.1
# 1774  R1345D        R1345D             3.1
# 1775  R1345D        R1345D             3.1
# 1776  R1345D        R1345D             3.1
# 1777  R1345D        R1345D             3.1
# 1778  R1345D        R1345D             3.1
#
#                                             task_events
# 45    protocols/r1/subjects/R1010J/experiments/FR1/s...
# 46    protocols/r1/subjects/R1010J/experiments/FR1/s...
# 247   protocols/r1/subjects/R1048E/experiments/FR1/s...
# 285   protocols/r1/subjects/R1054J/experiments/FR1/s...
# 286   protocols/r1/subjects/R1054J/experiments/FR1/s...
# 647   protocols/r1/subjects/R1112M/experiments/FR1/s...
# 648   protocols/r1/subjects/R1112M/experiments/FR1/s...
# 649   protocols/r1/subjects/R1112M/experiments/FR1/s...
# 726   protocols/r1/subjects/R1122E/experiments/FR1/s...
# 727   protocols/r1/subjects/R1122E/experiments/FR1/s...
# 794   protocols/r1/subjects/R1136N/experiments/FR1/s...
# 795   protocols/r1/subjects/R1136N/experiments/FR1/s...
# 802   protocols/r1/subjects/R1137E/experiments/FR1/s...
# 803   protocols/r1/subjects/R1137E/experiments/FR1/s...
# 804   protocols/r1/subjects/R1137E/experiments/FR1/s...
# 1639  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1640  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1641  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1642  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1643  protocols/r1/subjects/R1308T/experiments/FR1/s...
# 1709  protocols/r1/subjects/R1328E/experiments/FR1/s...
# 1710  protocols/r1/subjects/R1328E/experiments/FR1/s...
# 1774  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1775  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1776  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1777  protocols/r1/subjects/R1345D/experiments/FR1/s...
# 1778  protocols/r1/subjects/R1345D/experiments/FR1/s...

# %%
print(f'Sub-sessions for {selected_region}')
np.unique(cliff_notes_df.sub_sess_names)
print('Unique subs:')
print(np.unique(cliff_notes_df.sub_names))
# Out:
# Sub-sessions for ['left ca1', 'left ca2', 'left ca3', 'left dg', 'left sub', 'right ca1', 'right ca2', 'right ca3', 'right dg', 'right sub', ' left hippocampus', ' right hippocampus', 'left hippocampus', 'right hippocampus', '"ca1"', '"dg"', '"sub"', 'ca1', 'dg', 'sub']
# array(['R1010J-0', 'R1010J-1', 'R1048E-0', 'R1054J-0', 'R1054J-1',
#        'R1112M-0', 'R1112M-1', 'R1112M-2', 'R1122E-0', 'R1122E-1',
#        'R1136N-0', 'R1136N-1', 'R1137E-0', 'R1137E-1', 'R1137E-2',
#        'R1308T-0', 'R1308T-1', 'R1308T-2', 'R1308T-3', 'R1308T-4',
#        'R1328E-0', 'R1328E-1', 'R1345D-0', 'R1345D-1', 'R1345D-2',
#        'R1345D-3', 'R1345D-4'], dtype=object)
# Unique subs:
# ['R1010J' 'R1048E' 'R1054J' 'R1112M' 'R1122E' 'R1136N' 'R1137E' 'R1308T'
#  'R1328E' 'R1345D']
